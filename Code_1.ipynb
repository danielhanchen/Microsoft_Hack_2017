# %%
% matplotlib inline
from keras.models import Sequential
from keras.layers import Dense, Dropout
from keras.constraints import maxnorm
from keras.models import load_model
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.ensemble import RandomForestClassifier as rfc
import sklearn as sk

np.random.seed(1)
# Out:
# Using TensorFlow backend.

# %%
C = pd.read_csv("claims2.csv")
U = pd.read_csv("underwriting.csv")
P = pd.read_csv("policy.csv")

# %%
date_rec = C.pop("Date Received")

# %%
C['Suicide Indicator'] = C['Suicide Indicator'].astype('category')
columns = C.select_dtypes(['category']).columns
C[columns] = C[columns].apply(lambda fx: fx.cat.codes)

# %%
C
# Out:
#      Claimant Sex             Occupation Claim Type     Claim SubType  \
# 0            Male   Not Supplied              Death        Death Only
# 1            Male   Lawyer                    Death        Death Only
# 2            Male   Lawyer                    Death        Death Only
# 3            Male   Not Supplied              Death        Death Only
# 4            Male                unknown      Death        Death Only
# 5            Male   Boilermaker               Death        Death Only
# 6            Male   Locksmith                 Death        Death Only
# 7            Male                unknown      Death  Terminal illness
# 8            Male   Rigger / Dogman           Death        Death Only
# 9            Male   Farmer / Grazier          Death        Death Only
# 10         Female                unknown      Death        Death Only
# 11           Male                unknown      Death  Terminal illness
# ...
